# %%
import os
import pandas as pd
import lxml.etree as ET

# Pasta com os arquivos XML
pasta = 'G:\\Fiscal\\Fernanda\\Teste_xml\\'

# Lista para armazenar os dados de todos os arquivos
dados = []

# Iterar sobre todos os arquivos na pasta
for arquivo in os.listdir(pasta):
    if arquivo.endswith('.XML'):
        # Carregar o arquivo XML
        tree = ET.parse(pasta + arquivo)
        root = tree.getroot()

        # Informações Básicas
        cnfe = root.find('.//{http://www.portalfiscal.inf.br/nfe}infProt') 
        chave = cnfe.find('{http://www.portalfiscal.inf.br/nfe}chNFe').text   
           
        basico = root.find('.//{http://www.portalfiscal.inf.br/nfe}ide')        
        numero = basico.find('{http://www.portalfiscal.inf.br/nfe}nNF').text
        serie = basico.find('{http://www.portalfiscal.inf.br/nfe}serie').text
        data_emissao = basico.find('{http://www.portalfiscal.inf.br/nfe}dhEmi').text
        finalidade = basico.find('{http://www.portalfiscal.inf.br/nfe}finNFe').text
        ide = root.find('.//{http://www.portalfiscal.inf.br/nfe}ide')
        nfref = ide.find('{http://www.portalfiscal.inf.br/nfe}NFref')
        if nfref is not None:
            refnfe = nfref.find('{http://www.portalfiscal.inf.br/nfe}refNFe').text
        else:
            refnfe = None
        
        # Emitente
        emitente = root.find('.//{http://www.portalfiscal.inf.br/nfe}emit')
        cnpj_emitente = emitente.find('{http://www.portalfiscal.inf.br/nfe}CNPJ').text
        razao_social_emitente = emitente.find('{http://www.portalfiscal.inf.br/nfe}xNome').text

        # Destinatário
        destinatario = root.find('.//{http://www.portalfiscal.inf.br/nfe}dest')
        cnpj_destinatario = destinatario.find('{http://www.portalfiscal.inf.br/nfe}CNPJ').text
        razao_social_destinatario = destinatario.find('{http://www.portalfiscal.inf.br/nfe}xNome').text

        # Produtos
        produtos = root.findall('.//{http://www.portalfiscal.inf.br/nfe}prod')

        for produto in produtos:
            descricao_produto = produto.find('{http://www.portalfiscal.inf.br/nfe}xProd').text
            valor_total_produto = produto.find('{http://www.portalfiscal.inf.br/nfe}vProd').text
        cfop = produto.find('{http://www.portalfiscal.inf.br/nfe}CFOP').text
        unidade_comercial = produto.find('{http://www.portalfiscal.inf.br/nfe}uCom').text
        valor_unidade_comercial = produto.find('{http://www.portalfiscal.inf.br/nfe}vUnCom').text
        quantidade_comercial = produto.find('{http://www.portalfiscal.inf.br/nfe}qCom').text 
        unidade_tributaria = produto.find('{http://www.portalfiscal.inf.br/nfe}uTrib').text
        valor_unidade_tributaria = produto.find('{http://www.portalfiscal.inf.br/nfe}vUnTrib').text
        quantidade_tributaria = produto.find('{http://www.portalfiscal.inf.br/nfe}qTrib').text

        #Impostos
        impostos = root.findall('.//{http://www.portalfiscal.inf.br/nfe}imposto')
        for imposto in impostos:
            icms = imposto.find('{http://www.portalfiscal.inf.br/nfe}ICMS')
            if icms is not None:
                icms51 = icms.find('{http://www.portalfiscal.inf.br/nfe}ICMS51')
                icms40 = icms.find('{http://www.portalfiscal.inf.br/nfe}ICMS40')
                if icms51 is not None:
                    cst = icms51.find('{http://www.portalfiscal.inf.br/nfe}CST').text
                elif icms40 is not None:  
                    cst = icms40.find('{http://www.portalfiscal.inf.br/nfe}CST').text
                else:
                    cst = None
            else:
                cst = None


               
        # Adicionar as informações a lista de dados
        dados.append({
            'Número': numero,
            'Série': serie,
            'Data de emissão': data_emissao,
            'Finalidade': finalidade,
            'Chave': chave,
            'CNPJ do emitente': cnpj_emitente,
            'Razão social do emitente': razao_social_emitente,
            'CNPJ do destinatário': cnpj_destinatario,
            'Razão social do destinatário': razao_social_destinatario,
            'CFOP': cfop,
            'CST-ICMS': cst,
            'Descrição do produto': descricao_produto,
            'Unidade Comercial': unidade_comercial,
            'Valor Unitário Com.': valor_unidade_comercial,
            'Quantidade Com.': quantidade_comercial,
            'Unidade Tributária': unidade_tributaria,
            'Valor Unitário Trib.': valor_unidade_tributaria,
            'Quantidade Trib.': quantidade_tributaria,
            'Valor total do produto': valor_total_produto,
            'Nota referenciada': refnfe
        })

# Converter a lista de dados para um DataFrame do pandas
df = pd.DataFrame(dados)

# Escrever o DataFrame em um arquivo Excel
df.to_excel('G:\\Fiscal\\Fernanda\\Teste_xml\\nota_fiscal_info.xlsx', index=False)

# Exibir uma mensagem de sucesso
print("As informações foram gravadas com sucesso no arquivo nota_fiscal_info.xlsx")
# Out:
# As informações foram gravadas com sucesso no arquivo nota_fiscal_info.xlsx

# %%
print(df)
# Out:
#    Número Série            Data de emissão Finalidade  \
# 0     561     1  2024-03-20T17:38:00-04:00          2
# 1     562     1  2024-03-20T17:41:00-04:00          2
# 2     563     1  2024-03-20T17:47:00-04:00          2
# 3     564     1  2024-03-20T18:05:00-04:00          2
# 4     565     1  2024-03-20T18:07:00-04:00          2
# 5     566     1  2024-03-20T18:11:00-04:00          2
# 6     567     1  2024-03-20T18:15:00-04:00          2
# 7     568     1  2024-03-20T18:20:00-04:00          2
# 8     569     1  2024-03-20T18:23:00-04:00          2
# 9     570     1  2024-03-20T18:27:00-04:00          2
# 10    571     1  2024-03-20T18:29:00-04:00          2
# 11    572     1  2024-03-20T18:33:00-04:00          2
# 12    573     1  2024-03-20T18:36:00-04:00          2
# 13    574     1  2024-03-20T18:38:00-04:00          2
# 14    575     1  2024-03-20T18:41:00-04:00          2
# 15    576     1  2024-03-20T18:43:00-04:00          2
# 16  84833     0  2024-03-28T14:57:00-03:00          1
# 17  84836     0  2024-03-28T15:01:17-03:00          1
# 18  84838     0  2024-03-28T15:06:01-03:00          1
# 19  84840     0  2024-03-28T15:14:02-03:00          1
# 20  84841     0  2024-03-28T15:19:01-03:00          1
# 21  84842     0  2024-03-28T15:23:13-03:00          1
# 22  84843     0  2024-03-28T15:26:06-03:00          1
# 23  84844     0  2024-03-28T15:30:01-03:00          1
# 24  84852     0  2024-03-28T15:34:08-03:00          1
# 25  84853     0  2024-03-28T15:34:09-03:00          1
#
#                                            Chave CNPJ do emitente  \
# 0   51240317684007000172550010000005611412067844   17684007000172
# 1   51240317684007000172550010000005621783224163   17684007000172
# 2   51240317684007000172550010000005631170271270   17684007000172
# 3   51240317684007000172550010000005641377568619   17684007000172
# 4   51240317684007000172550010000005651482233815   17684007000172
# 5   51240317684007000172550010000005661963065070   17684007000172
# 6   51240317684007000172550010000005671633617107   17684007000172
# 7   51240317684007000172550010000005681175505186   17684007000172
# 8   51240317684007000172550010000005691629271743   17684007000172
# 9   51240317684007000172550010000005701371292708   17684007000172
# 10  51240317684007000172550010000005711232835580   17684007000172
# 11  51240317684007000172550010000005721418530639   17684007000172
# 12  51240317684007000172550010000005731209894180   17684007000172
# 13  51240317684007000172550010000005741332379813   17684007000172
# 14  51240317684007000172550010000005751683163594   17684007000172
# 15  51240317684007000172550010000005761770959254   17684007000172
# 16  35240354366547002269550000000848331301202032   54366547002269
# 17  35240354366547002269550000000848361197909742   54366547002269
# 18  35240354366547002269550000000848381523382602   54366547002269
# 19  35240354366547002269550000000848401172138591   54366547002269
# 20  35240354366547002269550000000848411099536585   54366547002269
# 21  35240354366547002269550000000848421911654904   54366547002269
# 22  35240354366547002269550000000848431286209635   54366547002269
# 23  35240354366547002269550000000848441194110400   54366547002269
# 24  35240354366547002269550000000848521824299711   54366547002269
# 25  35240354366547002269550000000848531480380286   54366547002269
#
#                              Razão social do emitente CNPJ do destinatário  \
# 0   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 1   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 2   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 3   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 4   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 5   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 6   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 7   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 8   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 9   GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 10  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 11  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 12  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 13  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 14  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 15  GACE AGRO GESTAO AGROLOGISTICA COMERCIO E EXPO...       19441249000241
# 16  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 17  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 18  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 19  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 20  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 21  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 22  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 23  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 24  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       19441249000160
# 25  COOP. DOS PLANTADORES DE CANA DO ESTADO SAO PAULO       09314867000277
#
#     Razão social do destinatário  CFOP CST-ICMS Descrição do produto  \
# 0   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 1   CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 2   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 3   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 4   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 5   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 6   CUTRALE TRADING BRASIL LTDA.  5502       41        SOJA EM GRAOS
# 7   CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 8   CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 9   CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 10  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 11  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 12  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 13  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 14  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 15  CUTRALE TRADING BRASIL LTDA.  5502       51        SOJA EM GRAOS
# 16   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 17   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 18   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 19   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 20   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 21   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 22   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 23   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 24   CUTRALE TRADING BRASIL LTDA  5502       41         SOJA EM GRAO
# 25        CARLOS CARMELO BRISCHI  1905       41         SOJA EM GRAO
#
#    Unidade Comercial Valor Unitário Com. Quantidade Com. Unidade Tributária  \
# 0                 KG        9.0376666667           120.0                TON
# 1                 KG      557.8400000000               0                TON
# 2                 KG        5.9393000000           200.0                TON
# 3                 KG       91.2600000000            10.0                TON
# 4                 KG        6.1389000000           200.0                TON
# 5                 KG       14.0424285714            70.0                TON
# 6                 KG        5.8502857143           210.0                TON
# 7                 KG      550.5300000000               0                TON
# 8                 KG      732.1000000000               0                TON
# 9                 KG      843.6300000000               0                TON
# 10                KG      819.7300000000               0                TON
# 11                KG      811.4000000000               0                TON
# 12                KG     1027.4600000000               0                TON
# 13                KG     2924.1700000000               0                TON
# 14                KG     3153.0800000000               0                TON
# 15                KG      310.6300000000               0                TON
# 16                KG    12182.1300000000          1.0000                TON
# 17                KG      490.6400000000          1.0000                TON
# 18                KG      521.7000000000          1.0000                TON
# 19                KG      797.6700000000          1.0000                TON
# 20                KG      121.5500000000          1.0000                TON
# 21                KG    12021.5300000000          1.0000                TON
# 22                KG    14307.2000000000          1.0000                TON
# 23                KG    18124.9500000000          1.0000                TON
# 24                KG    17811.4300000000          1.0000                TON
# 25                KG        2.0000000000      15542.4700                 KG
#
#    Valor Unitário Trib. Quantidade Trib. Valor total do produto  \
# 0       9037.6666666667             0.12                1084.52
# 1        557.8400000000                0                 557.84
# 2       5939.3000000000              0.2                1187.86
# 3      91260.0000000000             0.01                 912.60
# 4       6138.9000000000              0.2                1227.78
# 5      14042.4285714286             0.07                 982.97
# 6       5850.2857142857             0.21                1228.56
# 7        550.5300000000                0                 550.53
# 8        732.1000000000                0                 732.10
# 9        843.6300000000                0                 843.63
# 10       819.7300000000                0                 819.73
# 11       811.4000000000                0                 811.40
# 12      1027.4600000000                0                1027.46
# 13      2924.1700000000                0                2924.17
# 14      3153.0800000000                0                3153.08
# 15       310.6300000000                0                 310.63
# 16  12182130.0000000000           0.0010               12182.13
# 17    490640.0000000000           0.0010                 490.64
# 18    521700.0000000000           0.0010                 521.70
# 19    797670.0000000000           0.0010                 797.67
# 20    121550.0000000000           0.0010                 121.55
# 21  12021530.0000000000           0.0010               12021.53
# 22  14307200.0000000000           0.0010               14307.20
# 23  18124950.0000000000           0.0010               18124.95
# 24  17811430.0000000000           0.0010               17811.43
# 25         2.0000000000       15542.4700               31084.94
#
#                                Nota referenciada
# 0   51240317684007000172550010000005231701293265
# 1   51240317684007000172550010000005181406809035
# 2   51240317684007000172550010000005241413422938
# 3   51240317684007000172550010000005251984189663
# 4   51240317684007000172550010000005281776557290
# 5   51240317684007000172550010000005291632243598
# 6   51240317684007000172550010000005301904773355
# 7   51240317684007000172550010000005321881199563
# 8   51240317684007000172550010000005371527650644
# 9   51240317684007000172550010000005381769749607
# 10  51240317684007000172550010000005391909965363
# 11  51240317684007000172550010000005401835769508
# 12  51240317684007000172550010000005411803410544
# 13  51240317684007000172550010000005421657771212
# 14  51240317684007000172550010000005451757473959
# 15  51240317684007000172550010000005461601016809
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
# 20                                          None
# 21                                          None
# 22                                          None
# 23                                          None
# 24                                          None
# 25                                          None
